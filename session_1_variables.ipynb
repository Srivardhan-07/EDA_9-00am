# %%
for i in range(10000):
    pass

# %%
import time
time.sleep(5)
print("hi")
# Out:
# hi

# %%
a = 10
print(a)
# Out:
# 10

# %%
import time
time.sleep(10)
print("hi")
# Out:
# hi

# %%
a=10
print(a)
# Out:
# 10

# %%
a = 10

# %%
b = 100

# %% [markdown]
# a + b

# %%
number = 100

# %%
number
# Out:
# 100

# %%
- Python step by step process

- If we write 10 lines

- All 10 lines python execute one by one

- Even it is one cell has 10 lines

- You can write 10 lines in 10 cells
# Out:
#   Cell In[11], line 1
#     - Python step by step process
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Python step by step process
#
# - If we write 10 lines
#
# - All 10 lines python execute one by one
#
# - Even it is one cell has 10 lines
#
# - You can write 10 lines in 10 cells

# %%
import os
os.getcwd()
# current working directory
# we can able to see where is the python file available in my laptop
# Out:
# 'C:\\Users\\dhine\\OneDrive\\Documents\\Data science with AI\\Naresh IT\\Python Session'

# %% [markdown]
# ![STARK.jpg](attachment:e0b6051c-3dcc-46c1-8366-7d774253cfa2.jpg)

# %%
NUMBER = 100
NUMBER
# Out:
# 100

# %%
number = 200
number
# Out:
# 200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber = 400
NUMber
# Out:
# 400

# %%
number123 = 600
number123
# Out:
# 600

# %%
123number = 800
123number
# Out:
#   Cell In[11], line 1
#     123number = 800
#       ^
# SyntaxError: invalid decimal literal

# %%
num@ber = 200
num@ber    # special characters are not allowed
           # we only need black colour
# Out:
#   Cell In[12], line 1
#     num@ber = 200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
$number = 100
$number
# Out:
#   Cell In[13], line 1
#     $number = 100
#     ^
# SyntaxError: invalid syntax

# %%
num_ber =100
num_ber
# Out:
# 100

# %%
area_of_circle = 300
area_of_circle
# Out:
# 300

# %% [markdown]
# - num@ber = 300  #fail
#
# - $number = 49   # fail
#
# - num_ber = 98563   #works
#
# - areaofcircle = 3468  #fail
#
# - area_of_circle = 3468   #works
#
# - area of cirle = 3468    #fail

# %%
_ = 45769
_
# Out:
# 45769

# %%
if = 500 
if
# Out:
#   Cell In[18], line 1
#     if = 500
#        ^
# SyntaxError: invalid syntax

# %%
if
else
for
while
elif
False
in
# Out:
#   Cell In[19], line 1
#     if
#       ^
# SyntaxError: invalid syntax

# %%
sum = 500
sum      # sum is a math family
        # max is a math family
        # min is a math family
        # len is a math family
# Out:
# 500

# %%
l = [1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
sum(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sum(l)
#
# TypeError: 'int' object is not callable

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
l = [1,2,3,4]
sum(l)
# Out:
# 10

# %%
len(l)
# Out:
# 4

# %% [markdown]
# - Variables can be capital and small letters
# - Variables are case sensitive
# - Variables does not include special characters
# - Number as prefix not allowed
# - Varibales can have underscore [_]
# - Only underscore also possible
# - Reserved or keywords can not be variable
# - in built can not use as variable

# %%
# wap take 3 variables a, b, c
# provide the values
# find the average

a = 100
b = 200
c = 300
average = (a+b+c)/3
average
# Out:
# 200.0

# %%
# write a program calculate area of circle
# pi = 3.14 radius
# formula = pi*r*r

# wap ask the user
#

# %%
r = 5
pi = 3.14
area_of_circle = pi*r*r
area_of_circle
# Out:
# 78.5

# %%
bill_amount = 784358
tip_amount = 9876398
total_bill = bill_amount+tip_amount
total_bill
# Out:
# 10660756

# %%
weight_in_kgs = 100
weight_in_pounds = 100
pound = weight_value*2.2
pound
# Out:
# 22.0

# %%
money_dollars = 100
indian_money = 36

# %%
length  = 100
breadth = 200
area_of_rectangle = length*breadth
area_of_rectangle
# Out:
# 20000

# %%
import time
time.sleep(10)
print("hi")
# Out:
# hi
