# %% [markdown]
# **NOV - 17 - 2025**

# %% [markdown]
# **what we learn from last week**
#
# - variables
#
# - Data types
#
# - Type casting
#
# - print statements
#
# - input and round
#
# - we perform the basic 3

# %%
# Ramesh is a very good student
# he created a python code which do the addition of two numbers
# Ramesh felt that this code no one created till now 
# Ramesh decided he wants to handover that to entire world
# He approached anaconda organization
# Anaconda whoever installed your software
# My code should download automatically
# agreement
# addition.py

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import viratkohli
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import viratkohli
#
# ModuleNotFoundError: No module named 'viratkohli'

# %%
# Ramesh is so super excited
# he created subtraction , division, multiplication
#

# %% [markdown]
# **Module**
#
# - Module is a single python file
#
# - Having variables , functions, classes , methods
#
#   **package**
#
# - Package contains multiple python files
#
# - Assume that ramesh has created 4 python files
#
#     - add.py
#
#     - sub.py
#
#     - mul.py
#
#     - dic.py
#
# - All this four python files can save into a package
#
# - Package is a group of module

# %%
math_functions/

    add.py
    sub.py
    mul.py
    div.py

from math_functions import add
from math_functions import sub
from math_functions import mul
from math_functions import div
from math_functions import add, sub, mul, div

# %% [markdown]
# - every python file can be consider as module
#
# - every module has
#
# - Variables
#
# - functons
#
#      - sometimes we write these function under the **class**
#
#      - if a function is writting under the class we called as **method**
#
# - multiple methods will be available in a single python file

# %% [markdown]
# **random**

# %%
import random
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'math',
#  'open',
#  'os',
#  'quit',
#  'random',
#  'time']

# %% [markdown]
# - step 1 : import <module name>
#
# - step 2 : dir(<module name>)

# %%
import <module name>
import <random>
import random

# %%
import random   # correct
dir(random)

import <random>
dir (import random)  # wrong

# %%
import random 
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %% [markdown]
# **methods under a module also called as attributes**
#
# - random is a module
#
#      - randint is a method or attribute
#
#      - random is a method or attribute
#
# - Every method purpose is different the use case is different
#
# - if we want to call method or attribute , we need to call using module

# %%
import random
random.virat
# module 'random' has no attribute 'virat'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 import random
# ----> 2 random.virat
#
# AttributeError: module 'random' has no attribute 'virat'

# %%
import random
random.randint
# attribute randint available
# i missed the brackets then bound method is coming
# Out:
# <bound method Random.randint of <random.Random object at 0x000001880507B040>>

# %%
import random
random.randintt
# AttributeError: module 'random' has no attribute 'randintt'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 import random
# ----> 2 random.randintt
#
# AttributeError: module 'random' has no attribute 'randintt'

# %%
# step 1: import <module name>
# step 2: dir(<module name>)
# step 3: module_name.method_name
# when we do step-3 some times 
# we will get answer
# we will a get indication
# bound method or function

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001880507B040>>

# %%
# what is the works randint will do?
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
import random
random.randint(4,25)
# Out:
# 18

# %%
random.randint(5,20)
# Out:
# 17

# %%
# step 1: import <module name>
# step 2: dir(<module name>)
# step 3: module_name.method_name
# step 4: help(module_name.method_name)
# step 5: apply the use case

# %%
import random
dir(random)
random.randint
help(random.randint)
random.randint(1,10)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 8

# %%
# method : random method: random
import random
dir(random)
random.random

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
# module       method             hint
# random       randint            
# random       choice
# random       shuffle
# math          e
# math           pi
# math          sqrt
# math           pow
# math           sin
# math           ceil
# time           sleep
# os             getcwd
# os             listdir

# %%
import random
random.randint(15,75)
# Out:
# 20

# %%
import random
random.choice("""the GOAT""")
# Out:
# 'G'

# %%
l = [13,3423,5,345,4356,34]
random.shuffle(l)
l
# Out:
# [3423, 345, 34, 4356, 5, 13]

# %%
import math 
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(4637)
# Out:
# 68.09552114493287

# %%
math.pow(2,10)
# Out:
# 1024.0

# %%
math.sin(766786)
# Out:
# -0.9796113170209214

# %%
math.ceil(47.17)
# Out:
# 48

# %%
import time
time.sleep(5)
print('hi')
# Out:
# hi

# %%
import os
os.getcwd()     # current working directory
# Out:
# 'C:\\Users\\dhine\\OneDrive\\Documents\\Data science with AI\\Naresh IT\\Python Session'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment_1.ipynb',
#  'Assignment_2.ipynb',
#  'Assignment_3.ipynb',
#  'practice_session.ipynb',
#  'python_Data_types.ipynb',
#  'revision_data_types.ipynb',
#  'session_1_variables.ipynb',
#  'session_3.ipynb',
#  'session_5_Packeges.ipynb']

# %%
import time
start = time.time()
time.sleep(10)
print('srivardhan')
end = time.time()
end-start
# Out:
# srivardhan
# 10.001131772994995

# %%
import time
start = time.time()

print('srivardhan')
end = time.time()
end-start
# Out:
# srivardhan
# 0.00027751922607421875

# %%
import os
os.makedirs('VIP')

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
import string
string.digits
# Out:
# '0123456789'

# %%
import string
print(string.capwords(s, sep=","))
# Out:
# Apple,Banana,Cherry

# %%
import string
print(string.ascii_uppercase)
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
import string
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import string
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
import string
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
from random import randint
randint(23,54)
# Out:
# 38

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\dhine\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import langchain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import langchain
#
# ModuleNotFoundError: No module named 'langchain'

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
import langchain

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import langgraph

# %%
import tenserflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import tenserflow
#
# ModuleNotFoundError: No module named 'tenserflow'

# %%
import freeze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import freeze
#
# ModuleNotFoundError: No module named 'freeze'

# %%
import tensorflow
