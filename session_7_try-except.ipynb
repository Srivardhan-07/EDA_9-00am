# %% [markdown]
# **try-except**
#
# - try except is used to handle the exception mechanism
#
# - try and except is used to catch handle the errors
#
# - when we get the error python will stop the execution
#
# - using try except eventhough we get the errors , the execution will not stop
#
# - it will catch all the logical errors automatically
#
# - the actual code block will write in **try block**
#
# - if any erroor occures in try block , will catch the errors in **except** block
#
# - syntax errors will not catch

# %% [markdown]
# **errors**

# %% [markdown]
# - value error
#
# - type error
#
# - name error
#
# - attribute error
#
# - zero division error
#
# - module not found
#
# - file exist error

# %% [markdown]
# **divide by zero**

# %%
100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **name error**

# %%
a = sri
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = sri
#
# NameError: name 'sri' is not defined

# %% [markdown]
# **type error**

# %%
100+ 'sri'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 100+ 'sri'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **atribute error**

# %%
import math
math.sri
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import math
# ----> 2 math.sri
#
# AttributeError: module 'math' has no attribute 'sri'

# %% [markdown]
# **value error**

# %%
int('10.3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('10.3')
#
# ValueError: invalid literal for int() with base 10: '10.3'

# %%
import srivardhan
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import srivardhan
#
# ModuleNotFoundError: No module named 'srivardhan'

# %%
import os
os.makedirs('vardhan')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 import os
# ----> 2 os.makedirs('vardhan')
#
# File ~\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'vardhan'

# %%
try:
    <original code>
except Excepttion as e:
    print(e)

# %%
try:
    int('10.5')
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: '10.5'

# %%
try:
    int(10.5)
    ans=int(10.5)
    print(ans)
except Exception as e:
    print(e)
# Out:
# 10

# %%
try:
    print('hii')
    print('hello')
    int('10.4')
    print('good evening')
except Exception as srivardhan:
    print(srivardhan)
    print('you written wrong')
# Out:
# hii
# hello
# invalid literal for int() with base 10: '10.4'
# you written wrong

# %%
try:
    print('hii')
    print('hello')
    int('10.4')
    print('good evening')
except Exception as srivardhan:
    print(srivardhan)
    print('you written wrong')
# Out:
# hii
# hello
# invalid literal for int() with base 10: '10.4'
# you written wrong

# %%
try:
    int('10.33')
except ValueError:
    print("error: Value error")
# Out:
# error: Value error

# %%
try:
    import math
    math.string()
except AttributeError:
    print("error: Attribute error")
# Out:
# error: Attribute error

# %%
try:
    100/0
except ZeroDivisionError:
    print("error: Zero didvision error")
# Out:
# error: Zero didvision error

# %%
try:
    a = sri
    print(a)
except NameError:
    print("error: Name error")
# Out:
# error: Name error

# %%
try:
    100 + 'sri'
except TypeError:
    print('error: Type error')
# Out:
# error: Type error

# %%
try:
    import os
    os.makedirs('vardhan')
except FileExistsError:
    print("error: File exists error")
# Out:
# error: File exists error

# %%
try:
    import srivardhan
except ModuleNotFoundError:
    print('error: Module not found error')
# Out:
# error: Module not found error

# %%
try:
    salary = eval(input('enter the salary :'))
    tax_per = eval(input('enter the tax percentage :'))
    tax = salary*tax_per/100
    print(f'the tax amount is : {tax}')
except Exception as e:
    print(e)
# Out:
# enter the salary : 300000
# enter the tax percentage : 25
# the tax amount is : 75000.0

# %%
try:
    num = eval(input('enter a number :'))
    if num%2==0:
        print(f'the given number {num} is even')
    else:
        print(f'the given number {num} is odd')
except Exception as e:
    print(e)
# Out:
# enter a number : 3
# the given number 3 is odd

# %% [markdown]
# **try-except-finally**
#
# - original code in **try** bock
#
# - error catch in **except** block
#
# - **finally** block will activate either or try and except activate
#
# - assume that try block executed then finally block can also execute
#
# - assume that except block executed then also finally block execute

# %%
try:
    print('connection established ')
except Exception as e:
    print(e)
finally:
    print('connection closed')
# Out:
# connection established
# connection closed

# %%
import os
os.makedirs('vijay')
